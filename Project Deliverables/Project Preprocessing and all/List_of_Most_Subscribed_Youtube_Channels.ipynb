# %% [markdown]
# #**Project: Subscribers Galore: Exploring The World's Top YouTube Channels**
#
# ##Team_NM_ID: NM2023TMID00283
#
# #**Team_Leader: Krishna Kumar**
# ##Team_Member: Priya Kumari
# ##Team_Member: Vikram Kumar
# ##Team_Member: Devesh Kumar
#
# #**COLLEGE: JCT COLLEGE OF ENGINEERING AND TECHNOLOGY**

# %% [markdown]
# #1. Data Collection.

# %%
# Connection Installation for Kaggle Account.
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# Kaggle token copy in .json file
# !cp kaggle.json ~/.kaggle

# %% [markdown]
# #*Extract the dataset.

# %%
# Importing dataset from the Kaggle.
# !kaggle datasets download -d rajkumarpandey02/list-of-most-subscribed-youtube-channels-in-world
# Out:
# ...
#   0% 0.00/1.42k [00:00<?, ?B/s]
# 100% 1.42k/1.42k [00:00<00:00, 3.61MB/s]

# %% [markdown]
# #*Unzipping the content from zip file.

# %%
# Unzip the dataset, convert into csv file.
# !unzip /content/list-of-most-subscribed-youtube-channels-in-world.zip
# Out:
# Archive:  /content/list-of-most-subscribed-youtube-channels-in-world.zip
# replace List of most-subscribed YouTube channels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# #2. Importing some of important Libraries.

# %%
# Importing Important Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #3. Preprocessing the dataset.

# %%
# Loading CSV data to pandas data frames
df = pd.read_csv('/content/List of most-subscribed YouTube channels.csv')
df
# Out:
#     Unnamed: 0                     Rank                                 Name  \
# 0            0                        1                             T-Series
# 1            1                        2                            Cocomelon
# 2            2                        3  Sony Entertainment Television India
# 3            3                        4                              MrBeast
# 4            4                        5                            PewDiePie
# 5            5                        6                      Kids Diana Show
# 6            6                        7                          Like Nastya
# 7            7                        8                        Vlad and Niki
# 8            8                        9                                  WWE
# 9            9                       10                    Zee Music Company
# 10          10                       11                            Blackpink
# ...

# %%
# Get the size and shape of the dataset.
df.shape
# Out:
# (51, 9)

# %%
# First 7 rows of the dataset.
df.head(7)
# Out:
#    Unnamed: 0 Rank                                 Name  Link Brand channel  \
# 0           0    1                             T-Series  Link           Yes
# 1           1    2                            Cocomelon  Link           Yes
# 2           2    3  Sony Entertainment Television India  Link           Yes
# 3           3    4                              MrBeast  Link            No
# 4           4    5                            PewDiePie  Link            No
# 5           5    6                      Kids Diana Show  Link           Yes
# 6           6    7                          Like Nastya  Link            No
#
#   Subscribers (millions)     Primary language       Category        Country
# 0                    238          Hindi[7][8]          Music          India
# 1                    155              English      Education  United States
# 2                    153             Hindi[9]  Entertainment          India
# ...

# %%
# Last 7 rows of the dataset.
df.tail(7)
# Out:
#     Unnamed: 0                     Rank                     Name  \
# 44          44                       45                Bad Bunny
# 45          45                       46       SonyMusicIndiaVEVO
# 46          46                       47                 Shemaroo
# 47          47                       48               Get Movies
# 48          48                       49              Felipe Neto
# 49          49                       50                       A4
# 50          50  As of March 14, 2023UTC  As of March 14, 2023UTC
#
#                        Link            Brand channel   Subscribers (millions)  \
# 44                     Link                       No                     45.4
# 45                     Link                      Yes                     45.4
# 46                     Link                      Yes                     45.2
# 47                     Link                      Yes                       45
# ...

# %%
# Statistical measure\description about house price india dataset.
df.describe()
# Out:
#        Unnamed: 0
# count   51.000000
# mean    25.000000
# std     14.866069
# min      0.000000
# 25%     12.500000
# 50%     25.000000
# 75%     37.500000
# max     50.000000

# %%
# Statistical Information about house price india dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              51 non-null     int64
#  1   Rank                    51 non-null     object
#  2   Name                    51 non-null     object
#  3   Link                    51 non-null     object
#  4   Brand channel           51 non-null     object
#  5   Subscribers (millions)  51 non-null     object
#  6   Primary language        51 non-null     object
#  7   Category                51 non-null     object
#  8   Country                 51 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 3.7+ KB

# %%
# Checking for missing values.
df.isnull()
# Out:
#     Unnamed: 0   Rank   Name   Link  Brand channel  Subscribers (millions)  \
# 0        False  False  False  False          False                   False
# 1        False  False  False  False          False                   False
# 2        False  False  False  False          False                   False
# 3        False  False  False  False          False                   False
# 4        False  False  False  False          False                   False
# 5        False  False  False  False          False                   False
# 6        False  False  False  False          False                   False
# 7        False  False  False  False          False                   False
# 8        False  False  False  False          False                   False
# 9        False  False  False  False          False                   False
# 10       False  False  False  False          False                   False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Rank                      0
# Name                      0
# Link                      0
# Brand channel             0
# Subscribers (millions)    0
# Primary language          0
# Category                  0
# Country                   0
# dtype: int64

# %%
df.dropna()
# Out:
#     Unnamed: 0                     Rank                                 Name  \
# 0            0                        1                             T-Series
# 1            1                        2                            Cocomelon
# 2            2                        3  Sony Entertainment Television India
# 3            3                        4                              MrBeast
# 4            4                        5                            PewDiePie
# 5            5                        6                      Kids Diana Show
# 6            6                        7                          Like Nastya
# 7            7                        8                        Vlad and Niki
# 8            8                        9                                  WWE
# 9            9                       10                    Zee Music Company
# 10          10                       11                            Blackpink
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Name', 'Link', 'Brand channel',
#        'Subscribers (millions)', 'Primary language', 'Category', 'Country'],
#       dtype='object')

# %%
df.drop(df[df['Subscribers (millions)'] == 'As of March\xa014, 2023UTC'].index, inplace=True)

# %%
df['Subscribers (millions)']=df['Subscribers (millions)'].astype('float')

# %% [markdown]
# #4. Visualization of dataset based on some relation.

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Primary language',data=df)
plt.xticks(rotation=45)
plt.tight_layout()

# %%
sns.set(style="whitegrid", font_scale=1.2, rc={"figure.figsize":(20,10)})
sns.barplot(data=df,x = 'Name', y = 'Subscribers (millions)',color='green',saturation=0.35)
plt.xticks(rotation=90)
plt.tight_layout()
plt.xlabel('Name',fontsize=30)
plt.ylabel('Subscribers (millions)',fontsize=30)
# Out:
# Text(196.0, 0.5, 'Subscribers (millions)')

# %% [markdown]
# #*Pie_Chat Based on Subscribers.

# %%
import plotly.graph_objs as go

# Create a trace
trace = go.Pie(labels=df['Name'], values=df['Subscribers (millions)'])

# Create a layout
layout = go.Layout(title='Individual Distributions')

# Create a figure
fig = go.Figure(data=[trace], layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a trace
trace = go.Pie(labels=df['Category'], values=df['Subscribers (millions)'])

# Create a layout
layout = go.Layout(title='Category Distributions')

# Create a figure
fig = go.Figure(data=[trace], layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Show the plot
sns.countplot(x ='Category', data = df)
plt.show()

# %%
# Create a trace
trace = go.Pie(labels=df['Country'], values=df['Subscribers (millions)'])

# Create a layout
layout = go.Layout(title='Geographical Distributions')

# Create a figure
fig = go.Figure(data=[trace], layout=layout)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #5. Performation Testing.

# %%
X = df.drop('Rank', axis=1)
y = df['Rank']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
print(f'\n shape of X_train - {X_train.shape}\n')
print(f' shape of X_test - {X_test.shape}\n')
print(f' shape of y_train - {y_train.shape}\n')
print(f' shape of y_test - {y_test.shape}\n')
# Out:
#  shape of X_train - (40, 8)
#
#  shape of X_test - (10, 8)
#
#  shape of y_train - (40,)
#
#  shape of y_test - (10,)

# %% [markdown]
# #*Model Building.

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import Sequential
number_of_features = len(X.columns)
model = Sequential()
model.add(layer=Input(shape=number_of_features))
model.add(layer=Dense(units=32, activation='relu'))
model.add(layer=Dense(units=64, activation='relu'))
model.add(layer=Dense(units=128, activation='relu'))
model.add(layer=Dense(units=256, activation='relu'))
model.add(layer=Dense(units=512, activation='relu'))
model.add(layer=Dense(units=1024, activation='relu'))
model.add(layer=Dense(units=2048, activation='relu'))
model.add(layer=Dense(units=256, activation='relu'))
model.add(layer=Dense(units=128, activation='relu'))
model.add(layer=Dense(units=64, activation='relu'))
model.add(layer=Dense(units=32, activation='relu'))
model.add(layer=Dense(units=16, activation='relu'))
model.add(layer=Dense(units=1, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  dense_5 (Dense)             (None, 1024)              525312
#
#  dense_6 (Dense)             (None, 2048)              2099200
#
#  dense_7 (Dense)             (None, 256)               524544
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 16)                528
#
#  dense_12 (Dense)            (None, 1)                 17
#
# ...

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'mape'])

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (50, 8) (40, 8) (10, 8)

# %%
df['Subscribers (millions)']=df['Subscribers (millions)'].astype(float)
Category = df.groupby('Category')['Subscribers (millions)'].sum()
print(Category)
# Out:
# Category
# Education         334.1
# Entertainment    1138.1
# Film              142.1
# Games             204.3
# How-to             79.2
# Music            1500.7
# News               55.9
# Sports            152.8
# Name: Subscribers (millions), dtype: float64

# %%
df['Subscribers (millions)']=df['Subscribers (millions)'].astype(float)
Country = df.groupby('Country')['Subscribers (millions)'].sum()
print(Country)
# Out:
# Country
# Argentina                         56.0
# Belarus                           44.6
# Brazil                           111.3
# Canada                            71.1
# Chile                             47.6
# Cyprus[a]                         79.2
# El Salvador                       45.7
# India                           1377.6
# Mexico                            46.5
# Romania                           53.1
# Russia                           139.9
# South Korea                      294.3
# Sweden                           111.0
# Ukraine                          109.0
# United Kingdom                    53.0
# United States                    921.9
# United States ( Puerto Rico)      45.4
# Name: Subscribers (millions), dtype: float64
